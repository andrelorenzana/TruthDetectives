# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from pprint import pprint
pd.options.display.float_format = '{0:,.2f}'.format
import pymongo
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
db = client.nytapifinal_db
collection = db.all_articles
from datetime import datetime, date, timedelta

# %%
#Using the Article Search API
#https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20190101/body.search=Fake+News&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
artsearchfin_base_url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"
artsearchfin_query = "pub_date=20190101"
artsearchfin_key = "&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua"

artsearchfin_url = artsearchfin_base_url + artsearchfin_query + artsearchfin_key

artsearchfin_response = requests.get(artsearchfin_url).json()
print(len(artsearchfin_response))
pprint(artsearchfin_response)
# Out:
# 3
# {'copyright': 'Copyright (c) 2019 The New York Times Company. All Rights '
#               'Reserved.',
#  'response': {'docs': [{'_id': '4fd369d38eb7c8105d8bcbd0',
#                         'abstract': 'More than a few potential converts in '
#                                     'Iowa.',
#                         'blog': {},
#                         'byline': {'organization': None,
#                                    'original': 'By KATHARINE Q. SEELYE',
#                                    'person': [{'firstname': 'Katharine',
#                                                'lastname': 'SEELYE',
#                                                'middlename': 'Q.',
#                                                'organization': '',
#                                                'qualifier': None,
#                                                'rank': 1,
#                                                'role': 'reported',
#                                                'title': None}]},
#                         'document_type': 'blogpost',
#                         'headline': {'content_kicker': None,
#                                      'kicker': 'The Caucus',
#                                      'main': 'The Republicans in the Crowd',
#                                      'name': None,
#                                      'print_headline': None,
#                                      'seo': None,
#                                      'sub': None},
#                         'keywords': [{'major': None,
#                                       'name': 'type_of_material',
#                                       'rank': 1,
#                                       'value': 'News'}],
#                         'multimedia': [],
#                         'pub_date': '2007-12-15T17:54:33Z',
#                         'score': 1.0,
#                         'snippet': 'More than a few potential converts in '
#                                    'Iowa.',
#                         'source': 'The New York Times',
#                         'type_of_material': 'Blog',
#                         'web_url': 'https://thecaucus.blogs.nytimes.com/2007/12/15/the-republicans-in-the-crowd/',
#                         'word_count': 371},
#                        {'_id': '4fd369d38eb7c8105d8bcbda',
#                         'abstract': "Part of Mike Huckabee's campaign strategy "
#                                     'is to cut through political correctness '
#                                     'and talk matter of factly about Jesus '
#                                     'Christ.',
#                         'blog': {},
#                         'byline': {'organization': None,
#                                    'original': 'By ARIEL ALEXOVICH',
#                                    'person': [{'firstname': 'Ariel',
#                                                'lastname': 'ALEXOVICH',
#                                                'middlename': None,
#                                                'organization': '',
#                                                'qualifier': None,
#                                                'rank': 1,
#                                                'role': 'reported',
#                                                'title': None}]},
#                         'document_type': 'blogpost',
#                         'headline': {'content_kicker': None,
#                                      'kicker': 'The Caucus',
#                                      'main': 'The Early Word: Huckabee Scoffs '
#                                              "at 'Christophobia'",
#                                      'name': None,
#                                      'print_headline': None,
#                                      'seo': None,
#                                      'sub': None},
#                         'keywords': [{'major': None,
#                                       'name': 'type_of_material',
#                                       'rank': 1,
#                                       'value': 'News'}],
#                         'multimedia': [],
#                         'pub_date': '2007-12-21T08:32:28Z',
#                         'score': 1.0,
#                         'snippet': "Part of Mike Huckabee's campaign strategy "
#                                    'is to cut through political correctness '
#                                    'and talk matter of factly about Jesus '
#                                    'Christ.',
#                         'source': 'The New York Times',
#                         'type_of_material': 'Blog',
#                         'web_url': 'https://thecaucus.blogs.nytimes.com/2007/12/21/the-early-word-huckabee-scoffs-at-christophobia/',
#                         'word_count': 1783},
#                        {'_id': '4fd369d38eb7c8105d8bcbdd',
#                         'abstract': 'A more pointed attack on the Bush '
#                                     'presidency',
#                         'blog': {},
#                         'byline': {'organization': None,
#                                    'original': 'By PATRICK HEALY',
#                                    'person': [{'firstname': 'Patrick',
#                                                'lastname': 'HEALY',
#                                                'middlename': None,
#                                                'organization': '',
#                                                'qualifier': None,
#                                                'rank': 1,
#                                                'role': 'reported',
#                                                'title': None}]},
#                         'document_type': 'blogpost',
#                         'headline': {'content_kicker': None,
#                                      'kicker': 'The Caucus',
#                                      'main': 'Clinton Refines Message, With an '
#                                              'Edge',
#                                      'name': None,
#                                      'print_headline': None,
#                                      'seo': None,
#                                      'sub': None},
#                         'keywords': [{'major': None,
#                                       'name': 'type_of_material',
#                                       'rank': 1,
#                                       'value': 'News'}],
#                         'multimedia': [],
#                         'pub_date': '2007-12-26T21:48:38Z',
#                         'score': 1.0,
#                         'snippet': 'A more pointed attack on the Bush '
#                                    'presidency',
#                         'source': 'The New York Times',
#                         'type_of_material': 'Blog',
#                         'web_url': 'https://thecaucus.blogs.nytimes.com/2007/12/26/clinton-refines-her-message-with-an-edge/',
#                         'word_count': 823},
#                        {'_id': '4fd369d38eb7c8105d8bcbe5',
#                         'abstract': 'C-SPAN will be the only channel showing '
#                                     'live coverage of actual caucuses.',
#                         'blog': {},
#                         'byline': {'organization': None,
#                                    'original': 'By BRIAN STELTER',
#                                    'person': [{'firstname': 'Brian',
#                                                'lastname': 'STELTER',
#                                                'middlename': None,
#                                                'organization': '',
#                                                'qualifier': None,
#                                                'rank': 1,
#                                                'role': 'reported',
#                                                'title': None}]},
#                         'document_type': 'blogpost',
#                         'headline': {'content_kicker': None,
#                                      'kicker': 'The Caucus',
#                                      'main': 'The Caucuses, Gavel to Gavel, On '
#                                              'C-SPAN',
#                                      'name': None,
#                                      'print_headline': None,
#                                      'seo': None,
#                                      'sub': None},
#                         'keywords': [{'major': None,
#                                       'name': 'type_of_material',
#                                       'rank': 1,
#                                       'value': 'News'}],
#                         'multimedia': [],
#                         'pub_date': '2008-01-03T18:12:05Z',
#                         'score': 1.0,
#                         'snippet': 'C-SPAN will be the only channel showing '
#                                    'live coverage of actual caucuses.',
#                         'source': 'The New York Times',
#                         'type_of_material': 'Blog',
#                         'web_url': 'https://thecaucus.blogs.nytimes.com/2008/01/03/the-caucuses-gavel-to-gavel-on-c-span/',
#                         'word_count': 58},
#                        {'_id': '4fd369d38eb7c8105d8bcbe9',
#                         'abstract': 'Confused about who to support for '
#                                     'president? The markets can help you sort '
#                                     'it out.',
#                         'blog': {},
#                         'byline': {'organization': None,
#                                    'original': 'By DAVID LEONHARDT',
#                                    'person': [{'firstname': 'David',
#                                                'lastname': 'LEONHARDT',
#                                                'middlename': None,
#                                                'organization': '',
#                                                'qualifier': None,
#                                                'rank': 1,
#                                                'role': 'reported',
#                                                'title': None}]},
#                         'document_type': 'blogpost',
#                         'headline': {'content_kicker': None,
#                                      'kicker': 'The Caucus',
#                                      'main': 'The Odds of Becoming President',
#                                      'name': None,
#                                      'print_headline': None,
#                                      'seo': None,
#                                      'sub': None},
#                         'keywords': [{'major': None,
#                                       'name': 'type_of_material',
#                                       'rank': 1,
#                                       'value': 'News'}],
#                         'multimedia': [],
#                         'pub_date': '2008-01-04T10:51:10Z',
#                         'score': 1.0,
#                         'snippet': 'Confused about who to support for '
#                                    'president? The markets can help you sort '
#                                    'it out.',
#                         'source': 'The New York Times',
#                         'type_of_material': 'Blog',
#                         'web_url': 'https://thecaucus.blogs.nytimes.com/2008/01/04/the-odds-of-becoming-president/',
#                         'word_count': 433},
#                        {'_id': '4fd369d38eb7c8105d8bcbeb',
#                         'abstract': 'By the time they touched down in New '
#                                     'Hampshire last week, Hillary Rodham '
#                                     'Clinton and her aides had begun dissing '
#                                     'Iowa and its role in the process.',
#                         'blog': {},
#                         'byline': {'organization': None,
#                                    'original': 'By MATT BAI',
#                                    'person': [{'firstname': 'Matt',
#                                                'lastname': 'BAI',
#                                                'middlename': None,
#                                                'organization': '',
#                                                'qualifier': None,
#                                                'rank': 1,
#                                                'role': 'reported',
#                                                'title': None}]},
#                         'document_type': 'blogpost',
#                         'headline': {'content_kicker': None,
#                                      'kicker': 'The Caucus',
#                                      'main': 'A Candidate Spurned',
#                                      'name': None,
#                                      'print_headline': None,
#                                      'seo': None,
#                                      'sub': None},
#                         'keywords': [{'major': None,
#                                       'name': 'type_of_material',
#                                       'rank': 1,
#                                       'value': 'News'}],
#                         'multimedia': [],
#                         'pub_date': '2008-01-07T12:18:02Z',
#                         'score': 1.0,
#                         'snippet': 'By the time they touched down in New '
#                                    'Hampshire last week, Hillary Rodham '
#                                    'Clinton and her aides had begun dissing '
#                                    'Iowa and its role in the process.',
#                         'source': 'The New York Times',
#                         'type_of_material': 'Blog',
#                         'web_url': 'https://thecaucus.blogs.nytimes.com/2008/01/07/a-candidate-spurned/',
#                         'word_count': 745},
#                        {'_id': '4fd369d38eb7c8105d8bcbec',
#                         'abstract': 'It appears that Ron Paul might be the '
#                                     'front-runner in one area.',
#                         'blog': {},
#                         'byline': {'organization': None,
#                                    'original': 'By MARK LEIBOVICH',
#                                    'person': [{'firstname': 'Mark',
#                                                'lastname': 'LEIBOVICH',
#                                                'middlename': None,
#                                                'organization': '',
#                                                'qualifier': None,
#                                                'rank': 1,
#                                                'role': 'reported',
#                                                'title': None}]},
#                         'document_type': 'blogpost',
#                         'headline': {'content_kicker': None,
#                                      'kicker': 'The Caucus',
#                                      'main': "The 'Visibility Primary'",
#                                      'name': None,
#                                      'print_headline': None,
#                                      'seo': None,
#                                      'sub': None},
#                         'keywords': [{'major': None,
#                                       'name': 'type_of_material',
#                                       'rank': 1,
#                                       'value': 'News'}],
#                         'multimedia': [],
#                         'pub_date': '2008-01-08T13:28:48Z',
#                         'score': 1.0,
#                         'snippet': 'It appears that Ron Paul might be the '
#                                    'front-runner in one area.',
#                         'source': 'The New York Times',
#                         'type_of_material': 'Blog',
#                         'web_url': 'https://thecaucus.blogs.nytimes.com/2008/01/08/the-visibility-primary/',
#                         'word_count': 255},
#                        {'_id': '4fd369d38eb7c8105d8bcbed',
#                         'abstract': 'Republican and Democratic presidential '
#                                     'candidates set to make their final '
#                                     'arguments in person to as many New '
#                                     'Hampshire voters as they could find.',
#                         'blog': {},
#                         'byline': {'organization': 'THE NEW YORK TIMES',
#                                    'original': 'By THE NEW YORK TIMES',
#                                    'person': []},
#                         'document_type': 'blogpost',
#                         'headline': {'content_kicker': None,
#                                      'kicker': 'The Caucus',
#                                      'main': 'Photos: Sunday on the Trail',
#                                      'name': None,
#                                      'print_headline': None,
#                                      'seo': None,
#                                      'sub': None},
#                         'keywords': [{'major': None,
#                                       'name': 'type_of_material',
#                                       'rank': 1,
#                                       'value': 'News'}],
#                         'multimedia': [],
#                         'pub_date': '2008-01-06T20:13:52Z',
#                         'score': 1.0,
#                         'snippet': 'Republican and Democratic presidential '
#                                    'candidates set to make their final '
#                                    'arguments in person to as many New '
#                                    'Hampshire voters as they could find.',
#                         'source': 'The New York Times',
#                         'type_of_material': 'Blog',
#                         'web_url': 'https://thecaucus.blogs.nytimes.com/2008/01/06/photos-sunday-on-the-trail/',
#                         'word_count': 26},
#                        {'_id': '4fd369d38eb7c8105d8bcbf4',
#                         'abstract': "Hillary Rodham Clinton's campaign posted "
#                                     'two new videos online today -- one just '
#                                     'for the Web in which she takes questions '
#                                     'from young voters, and the other a new TV '
#                                     'ad for Nevada and South Carolina.',
#                         'blog': {},
#                         'byline': {'organization': None,
#                                    'original': 'By ARIEL ALEXOVICH',
#                                    'person': [{'firstname': 'Ariel',
#                                                'lastname': 'ALEXOVICH',
#                                                'middlename': None,
#                                                'organization': '',
#                                                'qualifier': None,
#                                                'rank': 1,
#                                                'role': 'reported',
#                                                'title': None}]},
#                         'document_type': 'blogpost',
#                         'headline': {'content_kicker': None,
#                                      'kicker': 'The Caucus',
#                                      'main': 'Clinton Found Her Voice, Now '
#                                              'Seeks Youth',
#                                      'name': None,
#                                      'print_headline': None,
#                                      'seo': None,
#                                      'sub': None},
#                         'keywords': [{'major': None,
#                                       'name': 'type_of_material',
#                                       'rank': 1,
#                                       'value': 'News'}],
#                         'multimedia': [],
#                         'pub_date': '2008-01-11T17:32:31Z',
#                         'score': 1.0,
#                         'snippet': "Hillary Rodham Clinton's campaign posted "
#                                    'two new videos online today -- one just '
#                                    'for the Web in which she takes questions '
#                                    'from young voters, and the other a new TV '
#                                    'ad for Nevada and South Carolina.',
#                         'source': 'The New York Times',
#                         'type_of_material': 'Blog',
#                         'web_url': 'https://thecaucus.blogs.nytimes.com/2008/01/11/clinton-found-her-voice-now-seeks-youth/',
#                         'word_count': 309},
#                        {'_id': '4fd369d38eb7c8105d8bcbf5',
#                         'abstract': 'The teachers union is challenging caucus '
#                                     'sites on the Vegas Strip.',
#                         'blog': {},
#                         'byline': {'organization': None,
#                                    'original': 'By JEFF ZELENY',
#                                    'person': [{'firstname': 'Jeff',
#                                                'lastname': 'ZELENY',
#                                                'middlename': None,
#                                                'organization': '',
#                                                'qualifier': None,
#                                                'rank': 1,
#                                                'role': 'reported',
#                                                'title': None}]},
#                         'document_type': 'blogpost',
#                         'headline': {'content_kicker': None,
#                                      'kicker': 'The Caucus',
#                                      'main': 'Obama Questions Nevada Caucus '
#                                              'Lawsuit',
#                                      'name': None,
#                                      'print_headline': None,
#                                      'seo': None,
#                                      'sub': None},
#                         'keywords': [{'major': None,
#                                       'name': 'type_of_material',
#                                       'rank': 1,
#                                       'value': 'News'}],
#                         'multimedia': [],
#                         'pub_date': '2008-01-13T19:55:41Z',
#                         'score': 1.0,
#                         'snippet': 'The teachers union is challenging caucus '
#                                    'sites on the Vegas Strip.',
#                         'source': 'The New York Times',
#                         'type_of_material': 'Blog',
#                         'web_url': 'https://thecaucus.blogs.nytimes.com/2008/01/13/obama-questions-nevada-caucus-lawsuit/',
#                         'word_count': 428}],
#               'meta': {'hits': 15430000, 'offset': 0, 'time': 1404}},
#  'status': 'OK'}

# %%
# Loop through datetimes
start = date(2015, 1, 1)
end = date(2019,1,17)
week = timedelta(days=1)

dt = start
while dt < end:
    #print(datetime.strftime(dt,'%Y%m%d'))
    try:
        artsearchfin_url = 'https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=%s&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua' % (datetime.strftime(dt,'%Y%m%d'))
        print('-----------------')
        #print(len(artsearchfin_response))
        print(artsearchfin_url)
        artsearchfin_response = requests.get(artsearchfin_url).json()
        #print(artsearchfin_response)
        # Loop through results to retrieve article title, header, and timestamp of article
        for result in artsearchfin_response['response']['docs']:
            #Title | Text | Author | Source | Label
            title = result['headline']['main']
            text = result['snippet']
            author = result['byline']['original']
            source = result['source']
            publication_date = result['pub_date']
            label = "Reliable"
            print(title)
            print(text)
            print (author)
            print (source)
            print(date)
            print(label)
            # Dictionary to be inserted into MongoDB
            post = {
                'Title': title,
                'Text': text,
                'Author': author,
                'Source': source,
               'Label': "Reliable"
                    }

            # Insert dictionary into MongoDB as a document
            collection.insert_one(post)
        
    except Exception as e:
        print(e)
    dt += week
# Out:
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180101&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# FOOD-PEACE PLAN SPLITS U.S. AIDES; Kennedy Acts to Halt Fight Over Shift in Jurisdiction
# WASHINGTON, May 2-- President Kennedy has intervened to halt a struggle for control of his $1,500,000,000-ayear Food for Peace program. The fight had split his immediate staff.
# By FELIX BELAIR Jr. Special to The New York Times
# The New York Times
# <class 'datetime.date'>
# Reliable
# 'byline'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180102&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# Clinton Refines Message, With an Edge
# A more pointed attack on the Bush presidency
# By PATRICK HEALY
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Caucuses, Gavel to Gavel, On C-SPAN
# C-SPAN will be the only channel showing live coverage of actual caucuses.
# By BRIAN STELTER
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Odds of Becoming President
# Confused about who to support for president? The markets can help you sort it out.
# By DAVID LEONHARDT
# The New York Times
# <class 'datetime.date'>
# Reliable
# A Candidate Spurned
# By the time they touched down in New Hampshire last week, Hillary Rodham Clinton and her aides had begun dissing Iowa and its role in the process.
# By MATT BAI
# The New York Times
# <class 'datetime.date'>
# Reliable
# The 'Visibility Primary'
# It appears that Ron Paul might be the front-runner in one area.
# By MARK LEIBOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Photos: Sunday on the Trail
# Republican and Democratic presidential candidates set to make their final arguments in person to as many New Hampshire voters as they could find.
# By THE NEW YORK TIMES
# The New York Times
# <class 'datetime.date'>
# Reliable
# Clinton Found Her Voice, Now Seeks Youth
# Hillary Rodham Clinton's campaign posted two new videos online today -- one just for the Web in which she takes questions from young voters, and the other a new TV ad for Nevada and South Carolina.
# By ARIEL ALEXOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Obama Questions Nevada Caucus Lawsuit
# The teachers union is challenging caucus sites on the Vegas Strip.
# By JEFF ZELENY
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Latest Thompson Ad Blitz
# The Republican candidate plans to broadcast a 60-second commercial on several networks and channels tomorrow night.
# By KATE PHILLIPS
# The New York Times
# <class 'datetime.date'>
# Reliable
# Atonement: Obits Were Dead on Arrival
# James Schamus, the man behind "atonement," offers a gracious "I told you so" to all the doubters.
# By THE BAGGER
# The New York Times
# <class 'datetime.date'>
# Reliable
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180103&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# Clinton Refines Message, With an Edge
# A more pointed attack on the Bush presidency
# By PATRICK HEALY
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Caucuses, Gavel to Gavel, On C-SPAN
# C-SPAN will be the only channel showing live coverage of actual caucuses.
# By BRIAN STELTER
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Odds of Becoming President
# Confused about who to support for president? The markets can help you sort it out.
# By DAVID LEONHARDT
# The New York Times
# <class 'datetime.date'>
# Reliable
# A Candidate Spurned
# By the time they touched down in New Hampshire last week, Hillary Rodham Clinton and her aides had begun dissing Iowa and its role in the process.
# By MATT BAI
# The New York Times
# <class 'datetime.date'>
# Reliable
# The 'Visibility Primary'
# It appears that Ron Paul might be the front-runner in one area.
# By MARK LEIBOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Photos: Sunday on the Trail
# Republican and Democratic presidential candidates set to make their final arguments in person to as many New Hampshire voters as they could find.
# By THE NEW YORK TIMES
# The New York Times
# <class 'datetime.date'>
# Reliable
# Clinton Found Her Voice, Now Seeks Youth
# Hillary Rodham Clinton's campaign posted two new videos online today -- one just for the Web in which she takes questions from young voters, and the other a new TV ad for Nevada and South Carolina.
# By ARIEL ALEXOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Obama Questions Nevada Caucus Lawsuit
# The teachers union is challenging caucus sites on the Vegas Strip.
# By JEFF ZELENY
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Latest Thompson Ad Blitz
# The Republican candidate plans to broadcast a 60-second commercial on several networks and channels tomorrow night.
# By KATE PHILLIPS
# The New York Times
# <class 'datetime.date'>
# Reliable
# Atonement: Obits Were Dead on Arrival
# James Schamus, the man behind "atonement," offers a gracious "I told you so" to all the doubters.
# By THE BAGGER
# The New York Times
# <class 'datetime.date'>
# Reliable
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180104&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# FOOD-PEACE PLAN SPLITS U.S. AIDES; Kennedy Acts to Halt Fight Over Shift in Jurisdiction
# WASHINGTON, May 2-- President Kennedy has intervened to halt a struggle for control of his $1,500,000,000-ayear Food for Peace program. The fight had split his immediate staff.
# By FELIX BELAIR Jr. Special to The New York Times
# The New York Times
# <class 'datetime.date'>
# Reliable
# 'byline'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180105&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# The Republicans in the Crowd
# More than a few potential converts in Iowa.
# By KATHARINE Q. SEELYE
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Early Word: Huckabee Scoffs at 'Christophobia'
# Part of Mike Huckabee's campaign strategy is to cut through political correctness and talk matter of factly about Jesus Christ.
# By ARIEL ALEXOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Clinton Refines Message, With an Edge
# A more pointed attack on the Bush presidency
# By PATRICK HEALY
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Caucuses, Gavel to Gavel, On C-SPAN
# C-SPAN will be the only channel showing live coverage of actual caucuses.
# By BRIAN STELTER
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Odds of Becoming President
# Confused about who to support for president? The markets can help you sort it out.
# By DAVID LEONHARDT
# The New York Times
# <class 'datetime.date'>
# Reliable
# A Candidate Spurned
# By the time they touched down in New Hampshire last week, Hillary Rodham Clinton and her aides had begun dissing Iowa and its role in the process.
# By MATT BAI
# The New York Times
# <class 'datetime.date'>
# Reliable
# The 'Visibility Primary'
# It appears that Ron Paul might be the front-runner in one area.
# By MARK LEIBOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Photos: Sunday on the Trail
# Republican and Democratic presidential candidates set to make their final arguments in person to as many New Hampshire voters as they could find.
# By THE NEW YORK TIMES
# The New York Times
# <class 'datetime.date'>
# Reliable
# Clinton Found Her Voice, Now Seeks Youth
# Hillary Rodham Clinton's campaign posted two new videos online today -- one just for the Web in which she takes questions from young voters, and the other a new TV ad for Nevada and South Carolina.
# By ARIEL ALEXOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Obama Questions Nevada Caucus Lawsuit
# The teachers union is challenging caucus sites on the Vegas Strip.
# By JEFF ZELENY
# The New York Times
# <class 'datetime.date'>
# Reliable
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180106&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# Clinton Refines Message, With an Edge
# A more pointed attack on the Bush presidency
# By PATRICK HEALY
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Caucuses, Gavel to Gavel, On C-SPAN
# C-SPAN will be the only channel showing live coverage of actual caucuses.
# By BRIAN STELTER
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Odds of Becoming President
# Confused about who to support for president? The markets can help you sort it out.
# By DAVID LEONHARDT
# The New York Times
# <class 'datetime.date'>
# Reliable
# A Candidate Spurned
# By the time they touched down in New Hampshire last week, Hillary Rodham Clinton and her aides had begun dissing Iowa and its role in the process.
# By MATT BAI
# The New York Times
# <class 'datetime.date'>
# Reliable
# The 'Visibility Primary'
# It appears that Ron Paul might be the front-runner in one area.
# By MARK LEIBOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Photos: Sunday on the Trail
# Republican and Democratic presidential candidates set to make their final arguments in person to as many New Hampshire voters as they could find.
# By THE NEW YORK TIMES
# The New York Times
# <class 'datetime.date'>
# Reliable
# Clinton Found Her Voice, Now Seeks Youth
# Hillary Rodham Clinton's campaign posted two new videos online today -- one just for the Web in which she takes questions from young voters, and the other a new TV ad for Nevada and South Carolina.
# By ARIEL ALEXOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Obama Questions Nevada Caucus Lawsuit
# The teachers union is challenging caucus sites on the Vegas Strip.
# By JEFF ZELENY
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Latest Thompson Ad Blitz
# The Republican candidate plans to broadcast a 60-second commercial on several networks and channels tomorrow night.
# By KATE PHILLIPS
# The New York Times
# <class 'datetime.date'>
# Reliable
# Atonement: Obits Were Dead on Arrival
# James Schamus, the man behind "atonement," offers a gracious "I told you so" to all the doubters.
# By THE BAGGER
# The New York Times
# <class 'datetime.date'>
# Reliable
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180107&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# Clinton Refines Message, With an Edge
# A more pointed attack on the Bush presidency
# By PATRICK HEALY
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Caucuses, Gavel to Gavel, On C-SPAN
# C-SPAN will be the only channel showing live coverage of actual caucuses.
# By BRIAN STELTER
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Odds of Becoming President
# Confused about who to support for president? The markets can help you sort it out.
# By DAVID LEONHARDT
# The New York Times
# <class 'datetime.date'>
# Reliable
# A Candidate Spurned
# By the time they touched down in New Hampshire last week, Hillary Rodham Clinton and her aides had begun dissing Iowa and its role in the process.
# By MATT BAI
# The New York Times
# <class 'datetime.date'>
# Reliable
# The 'Visibility Primary'
# It appears that Ron Paul might be the front-runner in one area.
# By MARK LEIBOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Photos: Sunday on the Trail
# Republican and Democratic presidential candidates set to make their final arguments in person to as many New Hampshire voters as they could find.
# By THE NEW YORK TIMES
# The New York Times
# <class 'datetime.date'>
# Reliable
# Clinton Found Her Voice, Now Seeks Youth
# Hillary Rodham Clinton's campaign posted two new videos online today -- one just for the Web in which she takes questions from young voters, and the other a new TV ad for Nevada and South Carolina.
# By ARIEL ALEXOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Obama Questions Nevada Caucus Lawsuit
# The teachers union is challenging caucus sites on the Vegas Strip.
# By JEFF ZELENY
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Latest Thompson Ad Blitz
# The Republican candidate plans to broadcast a 60-second commercial on several networks and channels tomorrow night.
# By KATE PHILLIPS
# The New York Times
# <class 'datetime.date'>
# Reliable
# Atonement: Obits Were Dead on Arrival
# James Schamus, the man behind "atonement," offers a gracious "I told you so" to all the doubters.
# By THE BAGGER
# The New York Times
# <class 'datetime.date'>
# Reliable
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180108&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# Clinton Refines Message, With an Edge
# A more pointed attack on the Bush presidency
# By PATRICK HEALY
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Caucuses, Gavel to Gavel, On C-SPAN
# C-SPAN will be the only channel showing live coverage of actual caucuses.
# By BRIAN STELTER
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Odds of Becoming President
# Confused about who to support for president? The markets can help you sort it out.
# By DAVID LEONHARDT
# The New York Times
# <class 'datetime.date'>
# Reliable
# A Candidate Spurned
# By the time they touched down in New Hampshire last week, Hillary Rodham Clinton and her aides had begun dissing Iowa and its role in the process.
# By MATT BAI
# The New York Times
# <class 'datetime.date'>
# Reliable
# The 'Visibility Primary'
# It appears that Ron Paul might be the front-runner in one area.
# By MARK LEIBOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Photos: Sunday on the Trail
# Republican and Democratic presidential candidates set to make their final arguments in person to as many New Hampshire voters as they could find.
# By THE NEW YORK TIMES
# The New York Times
# <class 'datetime.date'>
# Reliable
# Clinton Found Her Voice, Now Seeks Youth
# Hillary Rodham Clinton's campaign posted two new videos online today -- one just for the Web in which she takes questions from young voters, and the other a new TV ad for Nevada and South Carolina.
# By ARIEL ALEXOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Obama Questions Nevada Caucus Lawsuit
# The teachers union is challenging caucus sites on the Vegas Strip.
# By JEFF ZELENY
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Latest Thompson Ad Blitz
# The Republican candidate plans to broadcast a 60-second commercial on several networks and channels tomorrow night.
# By KATE PHILLIPS
# The New York Times
# <class 'datetime.date'>
# Reliable
# Atonement: Obits Were Dead on Arrival
# James Schamus, the man behind "atonement," offers a gracious "I told you so" to all the doubters.
# By THE BAGGER
# The New York Times
# <class 'datetime.date'>
# Reliable
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180109&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# Clinton Refines Message, With an Edge
# A more pointed attack on the Bush presidency
# By PATRICK HEALY
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Caucuses, Gavel to Gavel, On C-SPAN
# C-SPAN will be the only channel showing live coverage of actual caucuses.
# By BRIAN STELTER
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Odds of Becoming President
# Confused about who to support for president? The markets can help you sort it out.
# By DAVID LEONHARDT
# The New York Times
# <class 'datetime.date'>
# Reliable
# A Candidate Spurned
# By the time they touched down in New Hampshire last week, Hillary Rodham Clinton and her aides had begun dissing Iowa and its role in the process.
# By MATT BAI
# The New York Times
# <class 'datetime.date'>
# Reliable
# The 'Visibility Primary'
# It appears that Ron Paul might be the front-runner in one area.
# By MARK LEIBOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Photos: Sunday on the Trail
# Republican and Democratic presidential candidates set to make their final arguments in person to as many New Hampshire voters as they could find.
# By THE NEW YORK TIMES
# The New York Times
# <class 'datetime.date'>
# Reliable
# Clinton Found Her Voice, Now Seeks Youth
# Hillary Rodham Clinton's campaign posted two new videos online today -- one just for the Web in which she takes questions from young voters, and the other a new TV ad for Nevada and South Carolina.
# By ARIEL ALEXOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Obama Questions Nevada Caucus Lawsuit
# The teachers union is challenging caucus sites on the Vegas Strip.
# By JEFF ZELENY
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Latest Thompson Ad Blitz
# The Republican candidate plans to broadcast a 60-second commercial on several networks and channels tomorrow night.
# By KATE PHILLIPS
# The New York Times
# <class 'datetime.date'>
# Reliable
# Atonement: Obits Were Dead on Arrival
# James Schamus, the man behind "atonement," offers a gracious "I told you so" to all the doubters.
# By THE BAGGER
# The New York Times
# <class 'datetime.date'>
# Reliable
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180110&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# The Republicans in the Crowd
# More than a few potential converts in Iowa.
# By KATHARINE Q. SEELYE
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Early Word: Huckabee Scoffs at 'Christophobia'
# Part of Mike Huckabee's campaign strategy is to cut through political correctness and talk matter of factly about Jesus Christ.
# By ARIEL ALEXOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Clinton Refines Message, With an Edge
# A more pointed attack on the Bush presidency
# By PATRICK HEALY
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Caucuses, Gavel to Gavel, On C-SPAN
# C-SPAN will be the only channel showing live coverage of actual caucuses.
# By BRIAN STELTER
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Odds of Becoming President
# Confused about who to support for president? The markets can help you sort it out.
# By DAVID LEONHARDT
# The New York Times
# <class 'datetime.date'>
# Reliable
# A Candidate Spurned
# By the time they touched down in New Hampshire last week, Hillary Rodham Clinton and her aides had begun dissing Iowa and its role in the process.
# By MATT BAI
# The New York Times
# <class 'datetime.date'>
# Reliable
# The 'Visibility Primary'
# It appears that Ron Paul might be the front-runner in one area.
# By MARK LEIBOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Photos: Sunday on the Trail
# Republican and Democratic presidential candidates set to make their final arguments in person to as many New Hampshire voters as they could find.
# By THE NEW YORK TIMES
# The New York Times
# <class 'datetime.date'>
# Reliable
# Clinton Found Her Voice, Now Seeks Youth
# Hillary Rodham Clinton's campaign posted two new videos online today -- one just for the Web in which she takes questions from young voters, and the other a new TV ad for Nevada and South Carolina.
# By ARIEL ALEXOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Obama Questions Nevada Caucus Lawsuit
# The teachers union is challenging caucus sites on the Vegas Strip.
# By JEFF ZELENY
# The New York Times
# <class 'datetime.date'>
# Reliable
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180111&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180112&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180113&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180114&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180115&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180116&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180117&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180118&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180119&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180120&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180121&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180122&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180123&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180124&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180125&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180126&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180127&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180128&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180129&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180130&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180131&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180201&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180202&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180203&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180204&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180205&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180206&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180207&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180208&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180209&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180210&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180211&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180212&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180213&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180214&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180215&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180216&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180217&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180218&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180219&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180220&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180221&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180222&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180223&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180224&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180225&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180226&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180227&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180228&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180301&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180302&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180303&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180304&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180305&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180306&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180307&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180308&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180309&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180310&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180311&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180312&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180313&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180314&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180315&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180316&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180317&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180318&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180319&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180320&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180321&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180322&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180323&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180324&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180325&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180326&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180327&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180328&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180329&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180330&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180331&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180401&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180402&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180403&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180404&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180405&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180406&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180407&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180408&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180409&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# The Republicans in the Crowd
# More than a few potential converts in Iowa.
# By KATHARINE Q. SEELYE
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Early Word: Huckabee Scoffs at 'Christophobia'
# Part of Mike Huckabee's campaign strategy is to cut through political correctness and talk matter of factly about Jesus Christ.
# By ARIEL ALEXOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Clinton Refines Message, With an Edge
# A more pointed attack on the Bush presidency
# By PATRICK HEALY
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Caucuses, Gavel to Gavel, On C-SPAN
# C-SPAN will be the only channel showing live coverage of actual caucuses.
# By BRIAN STELTER
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Odds of Becoming President
# Confused about who to support for president? The markets can help you sort it out.
# By DAVID LEONHARDT
# The New York Times
# <class 'datetime.date'>
# Reliable
# A Candidate Spurned
# By the time they touched down in New Hampshire last week, Hillary Rodham Clinton and her aides had begun dissing Iowa and its role in the process.
# By MATT BAI
# The New York Times
# <class 'datetime.date'>
# Reliable
# The 'Visibility Primary'
# It appears that Ron Paul might be the front-runner in one area.
# By MARK LEIBOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Photos: Sunday on the Trail
# Republican and Democratic presidential candidates set to make their final arguments in person to as many New Hampshire voters as they could find.
# By THE NEW YORK TIMES
# The New York Times
# <class 'datetime.date'>
# Reliable
# Clinton Found Her Voice, Now Seeks Youth
# Hillary Rodham Clinton's campaign posted two new videos online today -- one just for the Web in which she takes questions from young voters, and the other a new TV ad for Nevada and South Carolina.
# By ARIEL ALEXOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Obama Questions Nevada Caucus Lawsuit
# The teachers union is challenging caucus sites on the Vegas Strip.
# By JEFF ZELENY
# The New York Times
# <class 'datetime.date'>
# Reliable
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180410&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# FOOD-PEACE PLAN SPLITS U.S. AIDES; Kennedy Acts to Halt Fight Over Shift in Jurisdiction
# WASHINGTON, May 2-- President Kennedy has intervened to halt a struggle for control of his $1,500,000,000-ayear Food for Peace program. The fight had split his immediate staff.
# By FELIX BELAIR Jr. Special to The New York Times
# The New York Times
# <class 'datetime.date'>
# Reliable
# 'byline'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180411&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# FOOD-PEACE PLAN SPLITS U.S. AIDES; Kennedy Acts to Halt Fight Over Shift in Jurisdiction
# WASHINGTON, May 2-- President Kennedy has intervened to halt a struggle for control of his $1,500,000,000-ayear Food for Peace program. The fight had split his immediate staff.
# By FELIX BELAIR Jr. Special to The New York Times
# The New York Times
# <class 'datetime.date'>
# Reliable
# 'byline'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180412&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# The Republicans in the Crowd
# More than a few potential converts in Iowa.
# By KATHARINE Q. SEELYE
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Early Word: Huckabee Scoffs at 'Christophobia'
# Part of Mike Huckabee's campaign strategy is to cut through political correctness and talk matter of factly about Jesus Christ.
# By ARIEL ALEXOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Clinton Refines Message, With an Edge
# A more pointed attack on the Bush presidency
# By PATRICK HEALY
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Caucuses, Gavel to Gavel, On C-SPAN
# C-SPAN will be the only channel showing live coverage of actual caucuses.
# By BRIAN STELTER
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Odds of Becoming President
# Confused about who to support for president? The markets can help you sort it out.
# By DAVID LEONHARDT
# The New York Times
# <class 'datetime.date'>
# Reliable
# A Candidate Spurned
# By the time they touched down in New Hampshire last week, Hillary Rodham Clinton and her aides had begun dissing Iowa and its role in the process.
# By MATT BAI
# The New York Times
# <class 'datetime.date'>
# Reliable
# The 'Visibility Primary'
# It appears that Ron Paul might be the front-runner in one area.
# By MARK LEIBOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Photos: Sunday on the Trail
# Republican and Democratic presidential candidates set to make their final arguments in person to as many New Hampshire voters as they could find.
# By THE NEW YORK TIMES
# The New York Times
# <class 'datetime.date'>
# Reliable
# Clinton Found Her Voice, Now Seeks Youth
# Hillary Rodham Clinton's campaign posted two new videos online today -- one just for the Web in which she takes questions from young voters, and the other a new TV ad for Nevada and South Carolina.
# By ARIEL ALEXOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Obama Questions Nevada Caucus Lawsuit
# The teachers union is challenging caucus sites on the Vegas Strip.
# By JEFF ZELENY
# The New York Times
# <class 'datetime.date'>
# Reliable
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180413&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# Clinton Refines Message, With an Edge
# A more pointed attack on the Bush presidency
# By PATRICK HEALY
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Caucuses, Gavel to Gavel, On C-SPAN
# C-SPAN will be the only channel showing live coverage of actual caucuses.
# By BRIAN STELTER
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Odds of Becoming President
# Confused about who to support for president? The markets can help you sort it out.
# By DAVID LEONHARDT
# The New York Times
# <class 'datetime.date'>
# Reliable
# A Candidate Spurned
# By the time they touched down in New Hampshire last week, Hillary Rodham Clinton and her aides had begun dissing Iowa and its role in the process.
# By MATT BAI
# The New York Times
# <class 'datetime.date'>
# Reliable
# The 'Visibility Primary'
# It appears that Ron Paul might be the front-runner in one area.
# By MARK LEIBOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Photos: Sunday on the Trail
# Republican and Democratic presidential candidates set to make their final arguments in person to as many New Hampshire voters as they could find.
# By THE NEW YORK TIMES
# The New York Times
# <class 'datetime.date'>
# Reliable
# Clinton Found Her Voice, Now Seeks Youth
# Hillary Rodham Clinton's campaign posted two new videos online today -- one just for the Web in which she takes questions from young voters, and the other a new TV ad for Nevada and South Carolina.
# By ARIEL ALEXOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Obama Questions Nevada Caucus Lawsuit
# The teachers union is challenging caucus sites on the Vegas Strip.
# By JEFF ZELENY
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Latest Thompson Ad Blitz
# The Republican candidate plans to broadcast a 60-second commercial on several networks and channels tomorrow night.
# By KATE PHILLIPS
# The New York Times
# <class 'datetime.date'>
# Reliable
# Atonement: Obits Were Dead on Arrival
# James Schamus, the man behind "atonement," offers a gracious "I told you so" to all the doubters.
# By THE BAGGER
# The New York Times
# <class 'datetime.date'>
# Reliable
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180414&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# The Republicans in the Crowd
# More than a few potential converts in Iowa.
# By KATHARINE Q. SEELYE
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Early Word: Huckabee Scoffs at 'Christophobia'
# Part of Mike Huckabee's campaign strategy is to cut through political correctness and talk matter of factly about Jesus Christ.
# By ARIEL ALEXOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Clinton Refines Message, With an Edge
# A more pointed attack on the Bush presidency
# By PATRICK HEALY
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Caucuses, Gavel to Gavel, On C-SPAN
# C-SPAN will be the only channel showing live coverage of actual caucuses.
# By BRIAN STELTER
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Odds of Becoming President
# Confused about who to support for president? The markets can help you sort it out.
# By DAVID LEONHARDT
# The New York Times
# <class 'datetime.date'>
# Reliable
# A Candidate Spurned
# By the time they touched down in New Hampshire last week, Hillary Rodham Clinton and her aides had begun dissing Iowa and its role in the process.
# By MATT BAI
# The New York Times
# <class 'datetime.date'>
# Reliable
# The 'Visibility Primary'
# It appears that Ron Paul might be the front-runner in one area.
# By MARK LEIBOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Photos: Sunday on the Trail
# Republican and Democratic presidential candidates set to make their final arguments in person to as many New Hampshire voters as they could find.
# By THE NEW YORK TIMES
# The New York Times
# <class 'datetime.date'>
# Reliable
# Clinton Found Her Voice, Now Seeks Youth
# Hillary Rodham Clinton's campaign posted two new videos online today -- one just for the Web in which she takes questions from young voters, and the other a new TV ad for Nevada and South Carolina.
# By ARIEL ALEXOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Obama Questions Nevada Caucus Lawsuit
# The teachers union is challenging caucus sites on the Vegas Strip.
# By JEFF ZELENY
# The New York Times
# <class 'datetime.date'>
# Reliable
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180415&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# FOOD-PEACE PLAN SPLITS U.S. AIDES; Kennedy Acts to Halt Fight Over Shift in Jurisdiction
# WASHINGTON, May 2-- President Kennedy has intervened to halt a struggle for control of his $1,500,000,000-ayear Food for Peace program. The fight had split his immediate staff.
# By FELIX BELAIR Jr. Special to The New York Times
# The New York Times
# <class 'datetime.date'>
# Reliable
# 'byline'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180416&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# The Republicans in the Crowd
# More than a few potential converts in Iowa.
# By KATHARINE Q. SEELYE
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Early Word: Huckabee Scoffs at 'Christophobia'
# Part of Mike Huckabee's campaign strategy is to cut through political correctness and talk matter of factly about Jesus Christ.
# By ARIEL ALEXOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Clinton Refines Message, With an Edge
# A more pointed attack on the Bush presidency
# By PATRICK HEALY
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Caucuses, Gavel to Gavel, On C-SPAN
# C-SPAN will be the only channel showing live coverage of actual caucuses.
# By BRIAN STELTER
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Odds of Becoming President
# Confused about who to support for president? The markets can help you sort it out.
# By DAVID LEONHARDT
# The New York Times
# <class 'datetime.date'>
# Reliable
# A Candidate Spurned
# By the time they touched down in New Hampshire last week, Hillary Rodham Clinton and her aides had begun dissing Iowa and its role in the process.
# By MATT BAI
# The New York Times
# <class 'datetime.date'>
# Reliable
# The 'Visibility Primary'
# It appears that Ron Paul might be the front-runner in one area.
# By MARK LEIBOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Photos: Sunday on the Trail
# Republican and Democratic presidential candidates set to make their final arguments in person to as many New Hampshire voters as they could find.
# By THE NEW YORK TIMES
# The New York Times
# <class 'datetime.date'>
# Reliable
# Clinton Found Her Voice, Now Seeks Youth
# Hillary Rodham Clinton's campaign posted two new videos online today -- one just for the Web in which she takes questions from young voters, and the other a new TV ad for Nevada and South Carolina.
# By ARIEL ALEXOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Obama Questions Nevada Caucus Lawsuit
# The teachers union is challenging caucus sites on the Vegas Strip.
# By JEFF ZELENY
# The New York Times
# <class 'datetime.date'>
# Reliable
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180417&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# The Republicans in the Crowd
# More than a few potential converts in Iowa.
# By KATHARINE Q. SEELYE
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Early Word: Huckabee Scoffs at 'Christophobia'
# Part of Mike Huckabee's campaign strategy is to cut through political correctness and talk matter of factly about Jesus Christ.
# By ARIEL ALEXOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Clinton Refines Message, With an Edge
# A more pointed attack on the Bush presidency
# By PATRICK HEALY
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Caucuses, Gavel to Gavel, On C-SPAN
# C-SPAN will be the only channel showing live coverage of actual caucuses.
# By BRIAN STELTER
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Odds of Becoming President
# Confused about who to support for president? The markets can help you sort it out.
# By DAVID LEONHARDT
# The New York Times
# <class 'datetime.date'>
# Reliable
# A Candidate Spurned
# By the time they touched down in New Hampshire last week, Hillary Rodham Clinton and her aides had begun dissing Iowa and its role in the process.
# By MATT BAI
# The New York Times
# <class 'datetime.date'>
# Reliable
# The 'Visibility Primary'
# It appears that Ron Paul might be the front-runner in one area.
# By MARK LEIBOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Photos: Sunday on the Trail
# Republican and Democratic presidential candidates set to make their final arguments in person to as many New Hampshire voters as they could find.
# By THE NEW YORK TIMES
# The New York Times
# <class 'datetime.date'>
# Reliable
# Clinton Found Her Voice, Now Seeks Youth
# Hillary Rodham Clinton's campaign posted two new videos online today -- one just for the Web in which she takes questions from young voters, and the other a new TV ad for Nevada and South Carolina.
# By ARIEL ALEXOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Obama Questions Nevada Caucus Lawsuit
# The teachers union is challenging caucus sites on the Vegas Strip.
# By JEFF ZELENY
# The New York Times
# <class 'datetime.date'>
# Reliable
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180418&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# The Republicans in the Crowd
# More than a few potential converts in Iowa.
# By KATHARINE Q. SEELYE
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Early Word: Huckabee Scoffs at 'Christophobia'
# Part of Mike Huckabee's campaign strategy is to cut through political correctness and talk matter of factly about Jesus Christ.
# By ARIEL ALEXOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Clinton Refines Message, With an Edge
# A more pointed attack on the Bush presidency
# By PATRICK HEALY
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Caucuses, Gavel to Gavel, On C-SPAN
# C-SPAN will be the only channel showing live coverage of actual caucuses.
# By BRIAN STELTER
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Odds of Becoming President
# Confused about who to support for president? The markets can help you sort it out.
# By DAVID LEONHARDT
# The New York Times
# <class 'datetime.date'>
# Reliable
# A Candidate Spurned
# By the time they touched down in New Hampshire last week, Hillary Rodham Clinton and her aides had begun dissing Iowa and its role in the process.
# By MATT BAI
# The New York Times
# <class 'datetime.date'>
# Reliable
# The 'Visibility Primary'
# It appears that Ron Paul might be the front-runner in one area.
# By MARK LEIBOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Photos: Sunday on the Trail
# Republican and Democratic presidential candidates set to make their final arguments in person to as many New Hampshire voters as they could find.
# By THE NEW YORK TIMES
# The New York Times
# <class 'datetime.date'>
# Reliable
# Clinton Found Her Voice, Now Seeks Youth
# Hillary Rodham Clinton's campaign posted two new videos online today -- one just for the Web in which she takes questions from young voters, and the other a new TV ad for Nevada and South Carolina.
# By ARIEL ALEXOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Obama Questions Nevada Caucus Lawsuit
# The teachers union is challenging caucus sites on the Vegas Strip.
# By JEFF ZELENY
# The New York Times
# ...
# By MARK LEIBOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Photos: Sunday on the Trail
# Republican and Democratic presidential candidates set to make their final arguments in person to as many New Hampshire voters as they could find.
# By THE NEW YORK TIMES
# The New York Times
# <class 'datetime.date'>
# Reliable
# Clinton Found Her Voice, Now Seeks Youth
# Hillary Rodham Clinton's campaign posted two new videos online today -- one just for the Web in which she takes questions from young voters, and the other a new TV ad for Nevada and South Carolina.
# By ARIEL ALEXOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Obama Questions Nevada Caucus Lawsuit
# The teachers union is challenging caucus sites on the Vegas Strip.
# By JEFF ZELENY
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Latest Thompson Ad Blitz
# The Republican candidate plans to broadcast a 60-second commercial on several networks and channels tomorrow night.
# By KATE PHILLIPS
# The New York Times
# <class 'datetime.date'>
# Reliable
# Atonement: Obits Were Dead on Arrival
# James Schamus, the man behind "atonement," offers a gracious "I told you so" to all the doubters.
# By THE BAGGER
# The New York Times
# <class 'datetime.date'>
# Reliable
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180822&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# Clinton Refines Message, With an Edge
# A more pointed attack on the Bush presidency
# By PATRICK HEALY
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Caucuses, Gavel to Gavel, On C-SPAN
# C-SPAN will be the only channel showing live coverage of actual caucuses.
# By BRIAN STELTER
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Odds of Becoming President
# Confused about who to support for president? The markets can help you sort it out.
# By DAVID LEONHARDT
# The New York Times
# <class 'datetime.date'>
# Reliable
# A Candidate Spurned
# By the time they touched down in New Hampshire last week, Hillary Rodham Clinton and her aides had begun dissing Iowa and its role in the process.
# By MATT BAI
# The New York Times
# <class 'datetime.date'>
# Reliable
# The 'Visibility Primary'
# It appears that Ron Paul might be the front-runner in one area.
# By MARK LEIBOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Photos: Sunday on the Trail
# Republican and Democratic presidential candidates set to make their final arguments in person to as many New Hampshire voters as they could find.
# By THE NEW YORK TIMES
# The New York Times
# <class 'datetime.date'>
# Reliable
# Clinton Found Her Voice, Now Seeks Youth
# Hillary Rodham Clinton's campaign posted two new videos online today -- one just for the Web in which she takes questions from young voters, and the other a new TV ad for Nevada and South Carolina.
# By ARIEL ALEXOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Obama Questions Nevada Caucus Lawsuit
# The teachers union is challenging caucus sites on the Vegas Strip.
# By JEFF ZELENY
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Latest Thompson Ad Blitz
# The Republican candidate plans to broadcast a 60-second commercial on several networks and channels tomorrow night.
# By KATE PHILLIPS
# The New York Times
# <class 'datetime.date'>
# Reliable
# Atonement: Obits Were Dead on Arrival
# James Schamus, the man behind "atonement," offers a gracious "I told you so" to all the doubters.
# By THE BAGGER
# The New York Times
# <class 'datetime.date'>
# Reliable
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180823&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# The Republicans in the Crowd
# More than a few potential converts in Iowa.
# By KATHARINE Q. SEELYE
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Early Word: Huckabee Scoffs at 'Christophobia'
# Part of Mike Huckabee's campaign strategy is to cut through political correctness and talk matter of factly about Jesus Christ.
# By ARIEL ALEXOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Clinton Refines Message, With an Edge
# A more pointed attack on the Bush presidency
# By PATRICK HEALY
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Caucuses, Gavel to Gavel, On C-SPAN
# C-SPAN will be the only channel showing live coverage of actual caucuses.
# By BRIAN STELTER
# The New York Times
# <class 'datetime.date'>
# Reliable
# The Odds of Becoming President
# Confused about who to support for president? The markets can help you sort it out.
# By DAVID LEONHARDT
# The New York Times
# <class 'datetime.date'>
# Reliable
# A Candidate Spurned
# By the time they touched down in New Hampshire last week, Hillary Rodham Clinton and her aides had begun dissing Iowa and its role in the process.
# By MATT BAI
# The New York Times
# <class 'datetime.date'>
# Reliable
# The 'Visibility Primary'
# It appears that Ron Paul might be the front-runner in one area.
# By MARK LEIBOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Photos: Sunday on the Trail
# Republican and Democratic presidential candidates set to make their final arguments in person to as many New Hampshire voters as they could find.
# By THE NEW YORK TIMES
# The New York Times
# <class 'datetime.date'>
# Reliable
# Clinton Found Her Voice, Now Seeks Youth
# Hillary Rodham Clinton's campaign posted two new videos online today -- one just for the Web in which she takes questions from young voters, and the other a new TV ad for Nevada and South Carolina.
# By ARIEL ALEXOVICH
# The New York Times
# <class 'datetime.date'>
# Reliable
# Obama Questions Nevada Caucus Lawsuit
# The teachers union is challenging caucus sites on the Vegas Strip.
# By JEFF ZELENY
# The New York Times
# <class 'datetime.date'>
# Reliable
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180824&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180825&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180826&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180827&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180828&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180829&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180830&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180831&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180901&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180902&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180903&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180904&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180905&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180906&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180907&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180908&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180909&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180910&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180911&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180912&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180913&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180914&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180915&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180916&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180917&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180918&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180919&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180920&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180921&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180922&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180923&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180924&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180925&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180926&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180927&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# 'response'
# -----------------
# https://api.nytimes.com/svc/search/v2/articlesearch.json?pub_date=20180928&api-key=SJOH17JUNSQbE7a5Kam5jckSbibo9qua
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3_\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-20ee20bf9878> in <module>()
#      12         #print(len(artsearchfin_response))
#      13         print(artsearchfin_url)
# ---> 14         artsearchfin_response = requests.get(artsearchfin_url).json()
#      15         #print(artsearchfin_response)
#      16         # Loop through results to retrieve article title, header, and timestamp of article
#
# ~\Anaconda3_\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~\Anaconda3_\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~\Anaconda3_\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~\Anaconda3_\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3_\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# ~\Anaconda3_\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# ~\Anaconda3_\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# ~\Anaconda3_\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# ~\Anaconda3_\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# ~\Anaconda3_\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# ~\Anaconda3_\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~\Anaconda3_\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     278     def recv_into(self, *args, **kwargs):
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#     282             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~\Anaconda3_\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1811             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1812         else:
# -> 1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# KeyboardInterrupt:
