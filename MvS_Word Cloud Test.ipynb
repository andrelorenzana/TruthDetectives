# %%
# Start with loading all necessary libraries
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
% matplotlib inline

# %%
# Load in the dataframe
df = pd.read_csv("Snopes Data File_Final.csv", index_col=0)
# Looking at first 5 rows of the dataset
df.reset_index(inplace=True)
df.head()
# Out:
#                                                Title  Text  Author  \
# 0  Did Theresa May Say Pedophiles Should Be Allow...   NaN     NaN
# 1  Does Congresswoman Ocasio-Cortez Say ‘Owning G...   NaN     NaN
# 2  Were Members of a ‘Midget Crime Gang’ Suspecte...   NaN     NaN
# 3  Did the IRS Admit It ‘Encourages Illegals’ to ...   NaN     NaN
# 4  Did Rashida Tlaib and Ilhan Omar Co-Sponsor a ...   NaN     NaN
#
#               Source       Label Unnamed: 5 Unnamed: 6
# 0  Snopes Aggregator  Unreliable        NaN        NaN
# 1  Snopes Aggregator  Unreliable        NaN        NaN
# 2  Snopes Aggregator  Unreliable        NaN        NaN
# 3  Snopes Aggregator  Unreliable        NaN        NaN
# 4  Snopes Aggregator  Unreliable        NaN        NaN

# %%
print("There are {} unreliable articles in this dataset. \n".format(df.shape[0],df.shape[1]))

print("There are {} categories in this dataset such as:\n {}...\n".format(len(df.Title.unique()),
                                                                           ",\n ".join(df.Title.unique()[0:5])))
# Out:
# There are 6600 unreliable articles in this dataset.
#
# There are 3590 categories in this dataset such as:
#  Did Theresa May Say Pedophiles Should Be Allowed to Adopt Children?,
#  Does Congresswoman Ocasio-Cortez Say ‘Owning Guns is Not a Right’ in the Constitution?,
#  Were Members of a ‘Midget Crime Gang’ Suspected of 55 Break-Ins?,
#  Did the IRS Admit It ‘Encourages Illegals’ to Steal Social Security Numbers for Taxes?,
#  Did Rashida Tlaib and Ilhan Omar Co-Sponsor a Bill to Recognize Muslim Holidays as Federal Holidays?...

# %%
# Assign Text:
text = df.Title[3]

# Create and generate a word cloud image:
wordcloud = WordCloud().generate(text)

wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
text = " ".join(review for review in df.Title)
print ("There are {} words in the Snopes dataset.".format(len(text)))
# Out:
# There are 402816 words in the Snopes dataset.

# %%
# Create stopword list:
stopwords = set(STOPWORDS)
stopwords.update(["$", "Is", "Did", "Why", "What", "Who", "Where"])

# Generate a word cloud image
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
#wordcloud.to_file("img/first_review.png")
